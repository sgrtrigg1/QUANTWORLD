# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys
project_root = "/content/drive/MyDrive/project_root"
os.chdir(project_root)
sys.path.append(project_root)

from quant_pipeline import QuantPipeline
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
qp = QuantPipeline(ticker="nvda", year=2025)
qp.run_all()
# Out:
# /content/drive/MyDrive/project_root/quant_pipeline/data.py:66: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
# [*********************100%***********************]  1 of 1 completed
# [DataCollector] Downloading Yahoo! Finance data for NVDA 2025...
# [DataCollector] Raw data saved to: /content/drive/MyDrive/project_root/data/Raw_Data/Raw_NVDA_2025.csv
# [DataCollector] Processed data saved to: /content/drive/MyDrive/project_root/data/Processed/Processed_NVDA_2025.csv
# [DataCollector] Raw data already collected: /content/drive/MyDrive/project_root/data/Raw_Data/Raw_NVDA_2025.csv
# [DataCollector] Using existing processed file: /content/drive/MyDrive/project_root/data/Processed/Processed_NVDA_2025.csv
# [OLS] Intercept: 107.5889
# [OLS] Slope:     0.384457
# [OLS] Saved global fit plot to: /content/drive/MyDrive/project_root/results/plots/NVDA_2025_ols_global.png
# First-half OLS model:
#   y = 126.629 + -0.040 * x
# ...
